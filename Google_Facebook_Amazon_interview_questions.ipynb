# %%
## Calculate the power of the number

li = input().split()

x = int(li[0])
n = int(li[1])

ans = 1

while n > 0:
    ans *= x
    n -= 1
    
print(ans)

# %%
## Fibonnaci series

def fibo(n):
    if n == 1 or n == 2:
        return 1
    else:
        return fibo(n-1) + fibo(n-2)
    
fibo(10)

# %%
## calculate the sum of the array

def sum_array(arr):
    
    if len(arr) == 1:
        return arr[0]
    else:
        return arr[0] + sum_array(arr[1:])
    
# sum_array([1,2,3,4,5])

n = int(input())
arr = list(int(i) for i in input().strip().split(' '))
print(sum_array(arr))

# %%
def sumArray(arr):
    # Please add your code here
    n = len(arr)
    if n == 1:
        return arr[0]
    else:
        return sumArray(arr[:n-1]) + arr[n-1]

# Main
from sys import setrecursionlimit
setrecursionlimit(11000)
n=int(input())
arr=list(int(i) for i in input().strip().split(' '))
print(sumArray(arr))

# %%
def sumArray2(arr):
    
    if len(arr) == 1:
        return arr[0]
    else:
        return arr[0] + sumArray2(arr[1:])
sumArray2([1,2,3,4,5])

# %%
### Check the number inside an array

def numCheck(arr, x):
    
    if len(arr) == 1:
        return False
    if arr[0] == x:
        return True
    
    return numCheck(arr[1:],x)

print(numCheck([1,2,3,4], 3))

n = int(input())
arr = list(int(i) for i in input().strip().split())
x = int(input())

if numCheck(arr,x):
    print('true')
else:
    print('false')

# %%
### Check whether the list is sorted or not(you need to define array and starting index)

def isSorted(arr, si):
    
    l =  len(arr)
    
    ## Checking if the array is empty or has only 1 element
    if si == l-1 or si == l:
        return True
    
    ## Checking if the starting index is greater than next element 
    if arr[si] > arr[si+1]:
        return False
    
    smallOutput = isSorted(arr, si+1)
    return smallOutput

isSorted([4,3,7,5,8,1],0)

# %%
def checkNum(arr, x):
    if len(arr) == 0:
        return False
    if arr[0] == x:
        return True
    return checkNum(arr[1:],x)
    
checkNum([4,6,3,5,6],6)

# %%
## Replace the occurance in the stringh

def count(arr, x):
    
    if len(arr) == 0:
        return 0
    
    if arr[0] == x:
        return 1 + count(arr[1:],x)
    
    else:
        return 0 + count(arr[1:],x)
    
count([1,2,3,1,1,3,1,1,1,1,3],1)

# %%
### Remove x from the string

def removeX(string):
    
    if len(string) == 0:
        return string
    
    if string[0] == 'x':
        return removeX(string[1:])
    
    return string[0] + removeX(string[1:])
    
removeX('axbx')

# %%
## replace pi with 3.14

def replacePI(s):
    
    if len(s) == 1 or len(s) == 2:
        return s
    
    if s[0] == 'p' and s[1] == 'i':
        return "3.14" + replacePI(s[2:])
    
    else:
        return s[0] + replacePI(s[1:])
    
replacePI('akhpiil')

# %%
## Remove duplicate elements from the string

def removeDup(s):
    
    if len(s) <= 1:
        return s
    
    s2 = removeDup(s[2:])
    
    if s[0] == s[1]:
        return s2
    else:
        return s[0] + s2
    
removeDup('aaaaakkkkkkiiiiiillllll')

# %%
## Binary search using recursion

def binarySearch(a,x,si,ei):
    
    if si > ei:
        return -1
    
    mid = (si+ei)//2
    
    if a[mid] == x:
        return mid
    
    if a[mid] > x:
        return binarySearch(a,x,si,mid-1)
    else:
        return binarySearch(a,x,mid+1,ei)
    
binarySearch([1,2,3,4],4,0,4)

# %%
## Quick sort using recursion 

def partition(arr, start, end):
    i = start-1
    pivot = arr[end]
    
    for j in range(start, end):
        if arr[j] <= pivot:
            i = i+1
            
            arr[i], arr[j] = arr[j], arr[i]
    arr[i+1], arr[end] = arr[end], arr[i+1]
    return (i+1)

def quickSort(arr, start, end):
    
    if len(arr) == 1:
        return arr
    
    if start < end:
        pi = partition(arr, start, end)
        quickSort(arr, start, pi-1)
        quickSort(arr, pi+1, end)
        
arr = [3,6,3,5,7,9,2,5,9,0]
n = len(arr)
quickSort(arr,0,n-1)
for i in range(n):
    print(arr[i], end=' ')

# %%
## merge sort

def mergesort(arr):
    if len(arr) > 1:
        
        mid = len(arr)//2
        
        L = arr[:mid]
        R = arr[mid:]
        
        mergesort(L)
        mergesort(R)
        
        i=j=k=0
        
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1
                
        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1
        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1
            
def printlist(arr):
    for i in range(len(arr)):
        print(arr[i], end=' ')
    print()
    
if __name__ == '__main__':
    arr = [3,2,5,6,3,2]
    printlist(arr)
    mergesort(arr)
    printlist(arr)

# %%
def mul(m,n):
    if n == 1:
        return m
    return m + mul(m, n-1)
mul(2,3)

# %%
def pow(x,n):
    if n == 0:
        return 1
    return x * pow(x, n-1)

pow(2,5)

# %%
## Find the intersection of arrau

def intersection(arr1, arr2, n, m):

# %%
def print_n(n):
    
    if n == 0:
        return 0
#     print(n)
    print_n(n-1)
    print(n)
    
print_n(5)

# %%
# %%time

'''Find the ceiling of a number '''

def binary_search(arr, x,si, ei):
    
    if si > ei:
        return 
    
    mid = (si+ei)//2
    
    if arr[mid] == x:
        return mid
    
    if arr[mid] > x:
        return binary_search(arr, x, si, mid-1) ## searching on left hand side
    else:
        return binary_search(arr, x, mid+1, ei) ## searching on right hand side

binary_search([2,3,5,5,9,14,16,18], 5,0,6)

# %%
# %%time

# def ceilSearch(arr, low, high, x):
    
#     if x <= arr[low]:
#         return low
#     if x > arr[high]:
#         return -1
    
#     mid = (low+high)//2
    
#     if arr[mid] == x:
#         return mid
    
#     elif arr[mid] < x:
#         if mid+1 <= high and x < arr[mid+1]:
#             return mid+1
#         else:
#             return ceilSearch(arr, mid+1, high, x)
#     else:
#         if mid-1 > low and x > arr[mid-1]:
#             return mid-1
#         else:
#             return ceilSearch(arr, low, mid-1,x)
        
        
# arr = [1, 2, 8, 10, 10, 12, 19]
# n = len(arr)
# x = 13
# index = ceilSearch(arr, 0, n-1, x);

# if index == -1:
#     print("ceiling of %d does not exist" % x)
# else:
#     print("ceiling of %d is %d"%(x,arr[index]))

# %%
### Find the ceiling of a number

# '''Ceiling = smallest number greater than equal to the target'''

# def getCeil(arr, x, si, ei):
    
#     ## Initialize Ceil
#     ceil = -1
    
#     while si <= ei:
        
#         mid = (si+ei)//2
        
#         if arr[mid] == x:
#             return arr[mid]
        
#         elif x < arr[mid]:
#             ceil = arr[mid]
#             ei = mid-1
#         else:
#             si = mid+1
    
#     return ceil

# arr = [3,6,2,6,9,4]
# arr.sort()
# print(arr)
# si = 0
# ei = len(arr)-1

# for i in range(max(arr)+2):
#     print(f'Number {i} ceis is {getCeil(arr,i,si,ei)}')

# getCeil(arr,14,si,ei)

# %%
### Find the floor of a number

'''Floor = largest number greater than equal to the target'''

def getFloor(arr, x, si, ei):
    
    floor = -1
    
    while si <= ei:
        
        mid = (si + ei)//2
        
        if arr[mid] == x:
            return arr[mid]
        
        elif x < arr[mid]:
            
            ei = mid -1 
        else:
            floor = arr[mid]
            si = mid + 1
    return floor

arr = [1, 4, 6, 8, 9]
arr.sort()
print(arr)
si = 0
ei = len(arr)-1

for i in range(max(arr)+2):
    print(f'Number {i} ceis is {getFloor(arr,i,si,ei)}')

# %%
class CeilingNumber:
    def getCeil(self,x, si, ei):
        ceil = -1
    
        while si <= ei:

            mid = (si+ei)//2

            if arr[mid] == x:
                return arr[mid]

            elif x < arr[mid]:
                ceil = arr[mid]
                ei = mid-1
                
            else:
                si = mid+1
        
        if x > len(arr)-1:
            print("The number not present inside the array")
        else:
            return ceil

arr = [3,6,2,6,9,4]
print("The unsorted array is :", arr)
arr.sort()
print("The sorted array is : ",arr)
si = 0
ei = len(arr)-1

# for i in range(max(arr)+2):
#     print(f'Number {i} ceis is {getCeil(arr,i,si,ei)}')

        
searchCiel = CeilingNumber
print("The ceil is :",searchCiel.getCeil(arr,10,si,ei))

# %%
class floorNumber:
    
    def getFloor(self,x, si, ei):
        
        floor = -1
        
        while si <= ei:
            
            mid = (si+ei)//2
            
            if arr[mid] == x:
                return arr[mid]
            
            elif x < arr[mid]:
                ei = mid-1
            else:
                floor = arr[mid]
                si = mid+1
        return floor

arr = [3,6,2,6,9,4]
print("The unsorted array is :", arr)
arr.sort()
print("The sorted array is : ",arr)
si = 0
ei = len(arr)-1

searchFloor = floorNumber
print("The floor of a number is : ", searchFloor.getFloor(arr, 5, si, ei))

# %%
## Find the smallest letter greater than the target

'''Similar to the problem ceiling of a number'''

class Solution:
    
    def nextGreatestLetter(self, letters, target):
        
        si = 0
        ei = len(letters) - 1
        
        while si <= ei:
            mid = (si+ei)//2
            
            if target < letters[mid]:
                ei = mid - 1  ## search on the left hand side
            else:
                si = mid+1   ## else search on the right hand side
        
        return letters[si % len(letters)]
    
ob = Solution()
ob.nextGreatestLetter(['c', 'f', 'j'], 'd')

# %%
## Find the smallest number greater than target

class Solution:
    
    def searchNumber(self, letters, target):
        
        start = 0
        end = len(letters) - 1
        
        while start <= end:
            mid = (start+end)//2
            
            if target < letters[mid]:
                end = mid-1
            else:
                start = mid+1
        
        return letters[start % len(letters)]
    
ob = Solution()
ob.searchNumber(['c','b','f'], 'd')

# %%
## Find the first and the last index of an element in a sorted array

'''arr = [5,7,7,7,7,8,8,10]  target = 7, output = [1,4]. Facebook Inteview problem

In this problem we have to apply Binary search twice.

'''

class FirstLastIndex:
    
    def searchRange(self, nums, target):
        res = [1,-1]
        low=0
        high=len(nums)
        
        while low<high:
            mid = int(low + (high-low)//2)
            
            if nums[mid] == target:
                high = mid
                res[0] = mid
                res[1] = mid
            
            elif nums[mid] < target:
                low = mid+1
            else:
                high=mid
                
        if res[0] == -1:
            return res
        low = res[0] + 1
        high = len(nums)
        
        while low < high:
            
            mid = int(low+ (high-low)//2)
            
            if nums[mid] == target:
                low = mid+1
                res[1] = mid
            elif nums[mid] < target:
                low = mid+1
            else:
                high=mid
            
        return res
                    
ob1 = FirstLastIndex()
print(ob1.searchRange([2,2,2,3,3,4,4,4,4,5,5,6], 4))

# %%
## Find the first and the last index of an element

'''Input = [1,2,2,2,3,4], Output = [1,3]'''

class FirstLast:
    
    def findRange(self, nums, target):
        
        res = [1,-1]
        low = 0
        high = len(nums)
        
        while low < high:
            
            mid = int(low + (high-low)/2)
            
            if nums[mid] == target:
                high = mid
                res[0] = mid
                res[1] = mid
            
            elif nums[mid] < target:
                low = mid+1
            else:
                high=mid
                
        if res[0] == -1:
            return res
        low = res[0]+1
        high = len(nums)
        
        while low < high:
            
            mid = int(low + (high-low)/2)
            
            if nums[mid] == target:
                low = mid+1
                res[1] = mid
            
            elif nums[mid] < target:
                low = mid + 1
            else:
                high = mid
                
        return res
                
ob1 = FirstLast()
ob1.findRange(['c', 'f', 'g'], 'k')

# %%
## Find the index of an element in an infinite array (Amazon)

def binary_search(arr, low, high, target):
    
    if low<=high:
        mid = low + (high-low)//2
        
        if arr[mid] == target:
            return mid
        if target < arr[mid]:
            return binary_search(arr, low, mid-1, target)
        return binary_search(arr, mid+1, high, target)
    return -1

def findPos(a, key):
    low,high, val = 0,1,arr[0]
    
    while val < key:
        low=high
        high=2*high
        val=arr[high]
    return binary_search(a, low,high,key)

# %%
arr = [3, 5, 7, 9, 10, 90, 100, 130, 140, 160, 170]
ans = findPos(arr,100)
if ans == -1:
    print ("Element not found")
else:
    print("Element found at index",ans)

# %%
## Find the index position of an element inside a sorted array

def binary_search(arr, low, high, target):
    if low <= high:
        mid = low+(high-low)//2
        if arr[mid] == target:
            return mid
        if target < arr[mid]:
            return binary_search(arr,low,mid-1,target)
        return binary_search(arr, mid+1, high, target)
    return -1

def findPos(a,key):
    low,high,val = 0,1,arr[0]
    while val < key:
        low=high
        high=2*high
        val=arr[high]
    return binary_search(a,low,high,key)

arr = [3, 5, 7, 9, 10, 90, 100, 130, 140, 160, 170]
ans = findPos(arr,90)

if ans == -1:
    print ("Element not found")
else:
    print("Element found at index",ans)

# %%
### Search in rotated sorted array (Amazon, Google)

class Solution:
    def search(self, arr, target):
        low=0
        high=len(arr)
        while low<high:
            mid=low+(high-low)//2
            if arr[mid]==target:
                return mid
            if arr[low] <= arr[mid]:
                if target >= arr[low] and target < arr[mid]:
                    high=mid
                else:
                    low=mid+1
            else:
                if target <= arr[high-1] and target > arr[mid]:
                    low=mid+1
                else:
                    high=mid
        return -1
    
ob1=Solution()
print(ob1.search([4,5,6,7,0,1,2],0))

# %%
## SEarch in a rotated sorted array (Amazon, Google)

class Solution:
    def search(self, arr, target):
        low=0
        high=len(arr)
        while low<=high:
            mid=low+(high-low)//2
            if arr[mid]==target:
                return mid
            if arr[low]<=arr[mid]: ## case 1 : from low to mid
                if target>=arr[low] and target<arr[mid]:
                    high=mid
                else:
                    low=mid+1
            else:
                if target<=arr[high-1] and target>arr[mid]: ## case 2 : mid to high
                    low=mid+1
                else:
                    high=mid                    
        return -1
    
ob1=Solution()
print(ob1.search([4,5,6,7,0,1,2],0))

# %%
### Search inside rotated sorted array of duplicate elements (Amazon, Google)

class Solution:
    def search(self,nums,target):
        low=0
        high=len(nums)
        while low<high:
            mid=low+(high-low)//2
            if nums[mid] == target:
                return True
            if nums[low]==nums[mid] and nums[high-1]==nums[mid]: ## Eliminating first and the last element
                low+=1
                high-=1
            if nums[low]<nums[mid]:
                if target>=nums[low] and target<nums[mid]:
                    high=mid
                else:
                    low=mid+1
            else:
                if target<=nums[high-1] and target>nums[mid]:
                    low=mid+1
                else:
                    high=mid
        return False
ob = Solution()
print(ob.search([2,5,6,0,0,1,2], 3))
# Out:
# False

# %%
## Count the rotations in a sorted array

def countRotations(arr):
    n=len(arr)
    low=0
    high=n-1
    while low<=high:
        mid=low+(high-low)//2
        ## Calculating the previoyus and the next index of mdi
        prev = (mid-1+n)%n
        next=(mid+1)%n
        
        ## checkuing if the mid is less than prev and next
        if arr[mid]<arr[prev] and arr[mid]<=arr[next]:
            return mid
        elif arr[mid]<arr[low]:
            end=mid-1
        elif arr[mid] > arr[low]:
            low=mid+1
        else:
            return 0
        
arr = [18,12]
n = len(arr)
print(countRotations(arr))
# Out:
# 0

# %%
### Split Array largets sum (Google)
class Solution:
    def splitArray(self, nums, m) -> int:
        low=max(nums)
        high=sum(nums)
        while low<=high:
            mid=low+(high-low)//2
            if self.count(nums,mid)<=m:
                high=mid
            elif self.count(nums,mid)>m:
                low=mid+1
                
    def count(self,n,arr):
        count=0
        summ=0
        for i in arr:
            if summ+i > n:
                count=0
                summ=0
                summ += i
            else:
                summ += i
        return count + 1

# %%
ob=Solution()
print(ob.splitArray([2,3,4,2,6,7],2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-2637dfc8cf6a> in <module>
#       1 ob=Solution()
# ----> 2 print(ob.splitArray([2,3,4,2,6,7],2))
#
# <ipython-input-2-da23a03e4849> in splitArray(self, nums, m)
#       6         while low<=high:
#       7             mid=low+(high-low)//2
# ----> 8             if self.count(nums,mid)<=m:
#       9                 high=mid
#      10             elif self.count(nums,mid)>m:
#
# <ipython-input-2-da23a03e4849> in count(self, n, arr)
#      14         count=0
#      15         summ=0
# ---> 16         for i in arr:
#      17             if summ+i > n:
#      18                 count=0
#
# TypeError: 'int' object is not iterable
